# %%
import tensorflow.compat.v1 as tf
import pandas as pd
import numpy as np
import os
import sys
import ipdb
import time
import cv2
from tensorflow.keras.preprocessing import sequence
import matplotlib.pyplot as plt
from tensorflow.keras.layers import LSTM
import fire
from elapsedtimer import ElapsedTimer
from pathlib import Path
print('tensorflow version:',tf.__version__)
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed, BatchNormalization, Activation, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K
from tensorflow.sparse import SparseTensor

from tqdm import tqdm
from tensorflow.keras.applications.inception_v3 import InceptionV3
import json
import pickle
from sklearn.utils import shuffle

import argparse
tf.compat.v1.disable_eager_execution()
tf.disable_v2_behavior()
# Out:
# tensorflow version: 2.11.0
# WARNING:tensorflow:From C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\compat\v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
def get_data(text_path, feat_path):
    text_data = pd.read_csv(text_path, sep=',')

    # Filter by English language
    text_data = text_data[text_data['Language'] == 'English']

    # Construct video names as concatenation of VideoID, Start, and End features
    text_data['video_name'] = text_data['VideoID'] + '_' + text_data['Start'].astype(int).astype(str) + '_' + text_data['End'].astype(int).astype(str) + '.npy'

    # Filter by videos with available feature files
    npy_files = [f for f in os.listdir(feat_path) if os.path.isfile(os.path.join(feat_path, f)) and f.endswith('.npy')]
    text_data = text_data[text_data['video_name'].isin(npy_files)]

    # Filter out rows with non-string descriptions
    text_data = text_data[text_data['Description'].map(lambda x: isinstance(x, str))]

    # Add video_path column
    text_data['video_path'] = text_data['video_name'].map(lambda x: os.path.join(feat_path, x))

    return text_data

# %%
class VideoCaptioning:
    
    
    def __init__(self,path_prj,caption_file,dfeat_dir,
                 cnn_feat_dim=4096,h_dim=512,
                 lstm_steps=80,video_steps=80,
                 out_steps=20, frame_step=80,
                 batch_size=8,learning_rate=1e-4,
                 epochs=10,model_path=None,
                 mode='train'):

        self.dim_image = cnn_feat_dim
        self.dim_hidden = h_dim
        self.batch_size = batch_size
        self.lstm_steps = lstm_steps
        self.video_lstm_step=video_steps
        self.caption_lstm_step=out_steps
        self.path_prj = Path(path_prj)
        self.mode = mode
        if mode == 'train':
            self.train_text_path = self.path_prj / caption_file
            self.train_feat_path = self.path_prj / dfeat_dir
        else:
            self.test_text_path = self.path_prj / caption_file
            self.test_feat_path = self.path_prj / dfeat_dir
        self.learning_rate = learning_rate
        self.epochs = epochs
        self.frame_step = frame_step
        
        self.model_path = model_path



        
    def build_model(self):
        graph = tf.Graph()
        with graph.as_default():
            # Defining the weights associated with the Network
            with tf.device('/cpu:0'): 
                self.word_emb = tf.Variable(tf.random.uniform([self.n_words, self.dim_hidden], -0.1, 0.1), name='word_emb')
                #print('shape self.word_emb ',self.word_emb.shape)
            self.lstm1 = tf.keras.layers.LSTMCell(self.dim_hidden)
            self.lstm2 = tf.keras.layers.LSTMCell(self.dim_hidden)
            self.encode_W = tf.Variable(tf.random.uniform([self.dim_image,self.dim_hidden], -0.1, 0.1), name='encode_W')
            self.encode_b = tf.Variable(tf.zeros([self.dim_hidden]), name='encode_b')

            self.word_emb_W = tf.Variable(tf.random.uniform([self.dim_hidden,self.n_words], -0.1,0.1), name='word_emb_W')
            self.word_emb_b = tf.Variable(tf.zeros([self.n_words]), name='word_emb_b')

            # Defining the Placeholders for the Model
            video = tf.compat.v1.placeholder(tf.float32, [self.batch_size, self.lstm_steps, self.dim_image])
            video_mask = tf.compat.v1.placeholder(tf.float32, [self.batch_size, self.lstm_steps])
            caption = tf.compat.v1.placeholder(tf.int32, [self.batch_size, self.lstm_steps+1])
            caption_mask = tf.compat.v1.placeholder(tf.float32, [self.batch_size, self.lstm_steps+1])
    
            init = tf.compat.v1.global_variables_initializer()
            sess = tf.compat.v1.InteractiveSession(graph=graph)
            sess.run(init)
    
            # Encoding the Video
            video_flat = tf.reshape(video, [-1, self.dim_image])
            image_emb = tf.matmul(video_flat, self.encode_W) + self.encode_b         
            image_emb = tf.reshape(image_emb, [self.batch_size, self.lstm_steps, self.dim_hidden])


            # Initializing the States and Padding for the LSTM Cells
            state1 = self.lstm1.get_initial_state(batch_size=self.batch_size, dtype=tf.float32)
            state2 = self.lstm2.get_initial_state(batch_size=self.batch_size, dtype=tf.float32)
            padding = tf.zeros([self.batch_size, self.dim_hidden])

            probs = []
            loss = 0.0

            #  Encoding Stage 
            for i in range(self.lstm_steps):
                if i > 0:
                    tf.compat.v1.get_variable_scope().reuse_variables()

                output1, state1 = self.lstm1(image_emb[:, i, :], state1)
                output2, state2 = self.lstm2(tf.concat([padding, output1], 1), state2)
                #print('shape output1',output1.shape)
                # Decoding Stage to generate Captions
            for i in range(self.caption_lstm_step):
                with tf.device("/cpu:0"):
                    current_embed = tf.nn.embedding_lookup(self.word_emb, caption[:, i])
                    #print('shape current_embed',current_embed.shape)
                with tf.compat.v1.variable_scope("LSTM1", reuse=tf.compat.v1.AUTO_REUSE):
                    output1, state1 = self.lstm1(padding, state1)

                with tf.compat.v1.variable_scope("LSTM2", reuse=tf.compat.v1.AUTO_REUSE):
                    output2, state2 = self.lstm2(tf.concat([current_embed, output1], axis=1), state2)

                labels = caption[:, i+1]
                onehot_labels = tf.one_hot(labels, depth=self.n_words)

                logit_words = tf.matmul(output2, self.word_emb_W) + self.word_emb_b

                # Computing the loss     
                loss += tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(labels=labels, logits=logit_words))


                probs.append(logit_words)
            optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate=self.learning_rate)
            with tf.GradientTape() as tape:
                gradients = optimizer.compute_gradients(loss, var_list=tf.compat.v1.trainable_variables())
            with tf.compat.v1.variable_scope(tf.compat.v1.get_variable_scope(), reuse=tf.compat.v1.AUTO_REUSE):
                train_op = optimizer.apply_gradients(gradients)

            return loss, video, video_mask, caption, caption_mask, probs, train_op


    def build_generator(self):
        graph = tf.Graph()
        with graph.as_default():
            with tf.device('/cpu:0'): 
                self.word_emb = tf.Variable(tf.random.uniform([self.n_words, self.dim_hidden], -0.1, 0.1), name='word_emb')
                print('shape self.word_emb ',self.word_emb.shape)
            self.lstm1 = tf.keras.layers.LSTMCell(self.dim_hidden)
            self.lstm2 = tf.keras.layers.LSTMCell(self.dim_hidden)
            
            self.encode_W = tf.Variable(tf.random.uniform([self.dim_image,self.dim_hidden], -0.1, 0.1), name='encode_W')
            self.encode_b = tf.Variable(tf.zeros([self.dim_hidden]), name='encode_b')

            self.word_emb_W = tf.Variable(tf.random.uniform([self.dim_hidden,self.n_words], -0.1,0.1), name='word_emb_W')
            self.word_emb_b = tf.Variable(tf.zeros([self.n_words]), name='word_emb_b')

            # Defining the Placeholders for the Model
            video = tf.compat.v1.placeholder(tf.float32, [self.batch_size, self.lstm_steps, self.dim_image])
            video_mask = tf.compat.v1.placeholder(tf.float32, [self.batch_size, self.lstm_steps])
            
            init = tf.compat.v1.global_variables_initializer()
            sess = tf.compat.v1.InteractiveSession(graph=graph)
            sess.run(init)

            video_flat = tf.reshape(video, [-1, self.dim_image])
            image_emb = tf.matmul(video_flat, self.encode_W) + self.encode_b         
            image_emb = tf.reshape(image_emb, [self.batch_size, self.lstm_steps, self.dim_hidden])

            state1 = self.lstm1.get_initial_state(batch_size=self.batch_size, dtype=tf.float32)
            state2 = self.lstm2.get_initial_state(batch_size=self.batch_size, dtype=tf.float32)
            padding = tf.zeros([self.batch_size, self.dim_hidden])

            generated_words = []

            probs = []
            embeds = []

            for i in range(0, self.video_lstm_step):
                if i > 0:
                    tf.compat.v1.get_variable_scope().reuse_variables()

                output1, state1 = self.lstm1(image_emb[:, i, :], state1)
                output2, state2 = self.lstm2(tf.concat([padding, output1], 1), state2)

            for i in range(0, self.caption_lstm_step):
                tf.compat.v1.get_variable_scope().reuse_variables()

                if i == 0:
                    with tf.device('/cpu:0'):
                        current_embed = tf.nn.embedding_lookup(self.word_emb, tf.ones([self.batch_size], dtype=tf.int64))

                with tf.compat.v1.variable_scope("LSTM1"):
                    output1, state1 = self.lstm1(padding, state1)

                with tf.compat.v1.variable_scope("LSTM2"):
                    output2, state2 = self.lstm2(tf.concat([current_embed, output1], axis=1), state2)

                logit_words = tf.matmul(output2, self.word_emb_W) + self.word_emb_b
                max_prob_index = tf.argmax(logit_words, 1)[0]
                generated_words.append(max_prob_index)
                probs.append(logit_words)

                with tf.device("/cpu:0"):
                    current_embed = tf.nn.embedding_lookup(self.word_emb, max_prob_index)
                    current_embed = tf.expand_dims(current_embed, 0)

                embeds.append(current_embed)

            return video, video_mask, generated_words, probs, embeds


    def get_data(text_path, feat_path):
        text_data = pd.read_csv(text_path, sep=',')

        # Filter by English language
        text_data = text_data[text_data['Language'] == 'English']

        # Construct video names as concatenation of VideoID, Start, and End features
        text_data['video_name'] = text_data['VideoID'] + '_' + text_data['Start'].astype(int).astype(str) + '_' + text_data['End'].astype(int).astype(str) + '.npy'

        # Filter by videos with available feature files
        npy_files = [f for f in os.listdir(feat_path) if os.path.isfile(os.path.join(feat_path, f)) and f.endswith('.npy')]
        text_data = text_data[text_data['video_name'].isin(npy_files)]

        # Filter out rows with non-string descriptions
        text_data = text_data[text_data['Description'].map(lambda x: isinstance(x, str))]

        # Add video_path column
        text_data['video_path'] = text_data['video_name'].map(lambda x: os.path.join(feat_path, x))

        return text_data

    def train_test_split(self,data,test_frac=0.2):
        indices = np.arange(len(data))
        np.random.shuffle(indices)
        train_indices_rec = int((1 - test_frac)*len(data))
        indices_train = indices[:train_indices_rec]
        indices_test = indices[train_indices_rec:]
        data_train, data_test = data.iloc[indices_train],data.iloc[indices_test]
        print(data_train.head())
        print(data_test.head())
        data_train.reset_index(inplace=True)
        data_test.reset_index(inplace=True)
        return data_train,data_test

    def get_test_data(self,text_path,feat_path):
        text_data = pd.read_csv(text_path, sep=',')
        text_data = text_data[text_data['Language'] == 'English']
        text_data['video_path'] = text_data.apply(lambda row: row['VideoID']+'_'+str(int(row['Start']))+'_'+str(int(row['End']))+'.npy', axis=1)
        text_data['video_path'] = text_data['video_path'].map(lambda x: os.path.join(feat_path, x))
        text_data = text_data[text_data['video_path'].map(lambda x: os.path.exists( x ))]
        text_data = text_data[text_data['Description'].map(lambda x: isinstance(x, str))]
    
        unique_filenames = sorted(text_data['video_path'].unique())
        test_data = text_data[text_data['video_path'].map(lambda x: x in unique_filenames)]
        return test_data       
        
    def create_word_dict(self,sentence_iterator, word_count_threshold=5):
        
        word_counts = {}
        sent_cnt = 0
        
        for sent in sentence_iterator:
            sent_cnt += 1
            for w in sent.lower().split(' '):
                word_counts[w] = word_counts.get(w, 0) + 1
        vocab = [w for w in word_counts if word_counts[w] >= word_count_threshold]
        
        idx2word = {}
        idx2word[0] = '<pad>'
        idx2word[1] = '<bos>'
        idx2word[2] = '<eos>'
        idx2word[3] = '<unk>'
    
        word2idx = {}
        word2idx['<pad>'] = 0
        word2idx['<bos>'] = 1
        word2idx['<eos>'] = 2
        word2idx['<unk>'] = 3
    
        for idx, w in enumerate(vocab):
            word2idx[w] = idx+4
            idx2word[idx+4] = w
    
        word_counts['<pad>'] = sent_cnt
        word_counts['<bos>'] = sent_cnt
        word_counts['<eos>'] = sent_cnt
        word_counts['<unk>'] = sent_cnt
    
        return word2idx,idx2word
        
        
        
    
    def train(self):
        data = get_data(r'C:\Users\User\Documents\P2M\test1\video_corpus.csv', r'C:\Users\User\Documents\P2M\test1\feature')
        #for idx, row in data.iterrows():
            #feature_path = os.path.join('path/to/feature_files/', row['video_name'])
        #data = self.get_data(self.train_text_path,self.train_feat_path)
        self.train_data,self.test_data = self.train_test_split(data,test_frac=0.2)
        self.train_data.to_csv(f'{self.path_prj}\\train.csv',index=False)
        self.test_data.to_csv(f'{self.path_prj}\\test.csv',index=False)

        print(f'Processed train file written to {self.path_prj}\train_corpus.csv')
        print(f'Processed test file written to {self.path_prj}\test_corpus.csv')
                

        train_captions = self.train_data['Description'].values
        test_captions = self.test_data['Description'].values
    
        captions_list = list(train_captions) 
        captions = np.asarray(captions_list, dtype=np.object)
    
        captions = list(map(lambda x: x.replace('.', ''), captions))
        captions = list(map(lambda x: x.replace(',', ''), captions))
        captions = list(map(lambda x: x.replace('"', ''), captions))
        captions = list(map(lambda x: x.replace('\n', ''), captions))
        captions = list(map(lambda x: x.replace('?', ''), captions))
        captions = list(map(lambda x: x.replace('!', ''), captions))
        captions = list(map(lambda x: x.replace('\\', ''), captions))
        captions = list(map(lambda x: x.replace('/', ''), captions))
    
        self.word2idx,self.idx2word = self.create_word_dict(captions, word_count_threshold=0)
        
        np.save(self.path_prj/ "word2idx",self.word2idx)
        np.save(self.path_prj/ "idx2word" ,self.idx2word)
        self.n_words = len(self.word2idx)
    
        tf_loss, tf_video,tf_video_mask,tf_caption,tf_caption_mask, tf_probs,train_op= self.build_model()
        sess = tf.compat.v1.InteractiveSession()
        
        saver = tf.compat.v1.train.Saver(max_to_keep=100, write_version=1)
        tf.compat.v1.global_variables_initializer().run()
    
    
        loss_out = open('loss.txt', 'w')
        val_loss = []
    
        for epoch in range(0,self.epochs):
            val_loss_epoch = []
    
            index = np.arange(len(self.train_data))

            self.train_data.reset_index()
            np.random.shuffle(index)
            self.train_data = self.train_data.loc[index]
    
            current_train_data = self.train_data.groupby(['video_path']).first().reset_index()

    
            for start, end in zip(
                    range(0, len(current_train_data),self.batch_size),
                    range(self.batch_size,len(current_train_data),self.batch_size)):
    
                start_time = time.time()
    
                current_batch = current_train_data[start:end]
                current_videos = current_batch['video_path'].values
    
                current_feats = np.zeros((self.batch_size, self.video_lstm_step,self.dim_image))
                current_feats_vals = list(map(lambda vid: np.load(vid),current_videos))
                current_feats_vals = np.array(current_feats_vals) 
    
                current_video_masks = np.zeros((self.batch_size,self.video_lstm_step))
    
                for ind,feat in enumerate(current_feats_vals):
                    current_feats[ind][:len(current_feats_vals[ind])] = feat
                    current_video_masks[ind][:len(current_feats_vals[ind])] = 1
    
                current_captions = current_batch['Description'].values
                current_captions = list(map(lambda x: '<bos> ' + x, current_captions))
                current_captions = list(map(lambda x: x.replace('.', ''), current_captions))
                current_captions = list(map(lambda x: x.replace(',', ''), current_captions))
                current_captions = list(map(lambda x: x.replace('"', ''), current_captions))
                current_captions = list(map(lambda x: x.replace('\n', ''), current_captions))
                current_captions = list(map(lambda x: x.replace('?', ''), current_captions))
                current_captions = list(map(lambda x: x.replace('!', ''), current_captions))
                current_captions = list(map(lambda x: x.replace('\\', ''), current_captions))
                current_captions = list(map(lambda x: x.replace('/', ''), current_captions))

    
                for idx, each_cap in enumerate(current_captions):
                    word = each_cap.lower().split(' ')
                    if len(word) < self.caption_lstm_step:
                        current_captions[idx] = current_captions[idx] + ' <eos>'
                    else:
                        new_word = ''
                        for i in range(self.caption_lstm_step-1):
                            new_word = new_word + word[i] + ' '
                        current_captions[idx] = new_word + '<eos>'
    
                current_caption_ind = []
                for cap in current_captions:
                    current_word_ind = []
                    for word in cap.lower().split(' '):
                        if word in self.word2idx:
                            current_word_ind.append(self.word2idx[word])
                        else:
                            current_word_ind.append(self.word2idx['<unk>'])
                    current_caption_ind.append(current_word_ind)
    
                current_caption_matrix = sequence.pad_sequences(current_caption_ind, padding='post', maxlen=self.lstm_steps)
                current_caption_matrix = np.hstack( [current_caption_matrix, np.zeros( [len(current_caption_matrix), 1] ) ] ).astype(int)
                current_caption_masks = np.zeros( (current_caption_matrix.shape[0], current_caption_matrix.shape[1]) )
                nonzeros = np.array( list(map(lambda x: (x != 0).sum() + 1, current_caption_matrix ) ))
    
                for ind, row in enumerate(current_caption_masks):
                    row[:nonzeros[ind]] = 1
    
                probs_val = sess.run(tf_probs, feed_dict={
                    tf_video:current_feats,
                    tf_caption: current_caption_matrix
                    })
    
                _, loss_val = sess.run(
                        [train_op, tf_loss],
                        feed_dict={
                            tf_video: current_feats,
                            tf_video_mask : current_video_masks,
                            tf_caption: current_caption_matrix,
                            tf_caption_mask: current_caption_masks
                            })
                val_loss_epoch.append(loss_val)
    
                print('Batch starting index: ', start, " Epoch: ", epoch, " loss: ", loss_val, ' Elapsed time: ', str((time.time() - start_time)))
                loss_out.write('epoch ' + str(epoch) + ' loss ' + str(loss_val) + '\n')
    
            # draw loss curve every epoch
            val_loss.append(np.mean(val_loss_epoch))
            plt_save_dir = self.path_prj / "loss_imgs"
            plt_save_img_name = str(epoch) + '.png'
            plt.plot(range(len(val_loss)),val_loss, color='g')
            plt.grid(True)
            plt.savefig(os.path.join('C:/Users/User/Documents/P2M/test1', plt_save_img_name))
    
            if np.mod(epoch, 9) == 0:
                print("Epoch ", epoch, " is done. Saving the model ...")
                saver = tf.train.Saver(write_version=tf.train.SaverDef.V2)
                saver.save(sess, os.path.join(self.path_prj, 'model'), global_step=epoch)
                print("Epoch ", epoch, " model Saved!")
        loss_out.close()
        
        
    
    def inference(self):
        self.test_data = self.get_test_data(self.test_text_path,self.test_feat_path)
        test_videos = self.test_data['video_path'].unique()
    
        self.idx2word = pd.Series(np.load(self.path_prj / "idx2word.npy", allow_pickle=True).tolist())
    
        self.n_words = len(self.idx2word)
        video_tf, video_mask_tf, caption_tf, probs_tf, last_embed_tf = self.build_generator()
    
        sess = tf.compat.v1.InteractiveSession()
    
        saver = tf.compat.v1.train.Saver()
        saver.restore(sess,self.model_path)
    
        f = open(f'{self.path_prj}/video_captioning_results.txt', 'w')
        for idx, video_feat_path in enumerate(test_videos):
            video_feat = np.load(video_feat_path)[None,...]
            if video_feat.shape[1] == self.frame_step:
                video_mask = np.ones((video_feat.shape[0], video_feat.shape[1]))
            else:
                continue
    
            gen_word_idx = sess.run(caption_tf, feed_dict={video_tf:video_feat, video_mask_tf:video_mask})
            gen_words = self.idx2word[gen_word_idx]
    
            punct = np.argmax(np.array(gen_words) == '<eos>') + 1
            gen_words = gen_words[:punct]
    
            gen_sent = ' '.join(gen_words)
            gen_sent = gen_sent.replace('<bos> ', '')
            gen_sent = gen_sent.replace(' <eos>', '')
            print(f'Video path {video_feat_path} : Generated Caption {gen_sent}')
            print(gen_sent,'\n')
            f.write(video_feat_path + '\n')
            f.write(gen_sent + '\n\n')

    def process_main(self):
        if self.mode == 'train':
            self.train()
        else:
            self.inference()
            #aaa

# %% [markdown]
# # a modifier model path

# %%
if __name__ == '__main__':
    with ElapsedTimer('Video Captioning'):
        VideoCaptioning(path_prj='C:/Users/User/Documents/P2M/test1', caption_file='video_corpus.csv', dfeat_dir='feature',
                        cnn_feat_dim=4096, h_dim=512, lstm_steps=80, video_steps=80, out_steps=20,
                        frame_step=80, batch_size=1, learning_rate=1e-4, epochs=100, model_path=r"C:\Users\User\Documents\P2M\test1\model-99",
                        mode='test').process_main()
# Out:
# shape self.word_emb  (12022, 512)
# C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\client\session.py:1769: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# INFO:tensorflow:Restoring parameters from C:\Users\User\Documents\P2M\test1\model-99
# Video path C:\Users\User\Documents\P2M\test1\feature\mv89psg6zh4_33_46.npy : Generated Caption a bird is running in a sink
# a bird is running in a sink
#
# Video path C:\Users\User\Documents\P2M\test1\feature\ZbzDGXEwtGc_6_15.npy : Generated Caption a plane is flying
# a plane is flying
#
# Video path C:\Users\User\Documents\P2M\test1\feature\g36ho6UrBz0_5_20.npy : Generated Caption a man is playing a guitar
# a man is playing a guitar
#
# Video path C:\Users\User\Documents\P2M\test1\feature\04Gt01vatkk_248_265.npy : Generated Caption a woman is cutting an onion
# a woman is cutting an onion
#
# Video path C:\Users\User\Documents\P2M\test1\feature\buJ5HDCinrM_150_166.npy : Generated Caption a woman is applying makeup to her face
# a woman is applying makeup to her face
#
# Video path C:\Users\User\Documents\P2M\test1\feature\M_TP6UTrh30_343_358.npy : Generated Caption a band is performing on stage
# a band is performing on stage
#
# Video path C:\Users\User\Documents\P2M\test1\feature\8mSUD7JGNO0_174_181.npy : Generated Caption a woman is riding a horse
# a woman is riding a horse
#
# Video path C:\Users\User\Documents\P2M\test1\feature\ljGcQocjSs4_38_60.npy : Generated Caption a man is shooting a gun
# a man is shooting a gun
#
# Video path C:\Users\User\Documents\P2M\test1\feature\n2NLoLNecgI_168_178.npy : Generated Caption a woman is playing a violin
# a woman is playing a violin
#
# Video path C:\Users\User\Documents\P2M\test1\feature\6q1dX6thX3E_286_295.npy : Generated Caption a man is talking to a woman
# a man is talking to a woman
#
# Video path C:\Users\User\Documents\P2M\test1\feature\mFCf8lLXrUc_25_35.npy : Generated Caption a woman is peeling a mango
# a woman is peeling a mango
#
# Video path C:\Users\User\Documents\P2M\test1\feature\6eokrw6_bjU_1_9.npy : Generated Caption a woman is shooting a gun
# a woman is shooting a gun
#
# Video path C:\Users\User\Documents\P2M\test1\feature\E2r6nnkwl0c_6_18.npy : Generated Caption people are swimming
# people are swimming
#
# Video path C:\Users\User\Documents\P2M\test1\feature\n016q1w8Q30_2_11.npy : Generated Caption a man is cutting a card with a piece of paper
# a man is cutting a card with a piece of paper
#
# Video path C:\Users\User\Documents\P2M\test1\feature\rQuNYxNmA6M_0_4.npy : Generated Caption a man is hitting a soccer ball
# a man is hitting a soccer ball
#
# Video path C:\Users\User\Documents\P2M\test1\feature\ByGspTdA1ug_16_24.npy : Generated Caption a man is playing with a cat
# a man is playing with a cat
#
# Video path C:\Users\User\Documents\P2M\test1\feature\-_hbPLsZvvo_323_328.npy : Generated Caption a woman is putting oil on a plate
# a woman is putting oil on a plate
#
# Video path C:\Users\User\Documents\P2M\test1\feature\6t0BpjwYKco_217_229.npy : Generated Caption a woman is cutting meat
# a woman is cutting meat
#
# Video path C:\Users\User\Documents\P2M\test1\feature\MTkGPfMRXtc_5_21.npy : Generated Caption a woman is making a closet
# a woman is making a closet
#
# Video path C:\Users\User\Documents\P2M\test1\feature\aeA-HN7BMdo_34_41.npy : Generated Caption a woman is cutting up broccoli
# a woman is cutting up broccoli
#
# Video path C:\Users\User\Documents\P2M\test1\feature\WWf0Z6ak3Dg_5_15.npy : Generated Caption a dog is playing with a ball
# a dog is playing with a ball
#
# Video path C:\Users\User\Documents\P2M\test1\feature\DBvSfds3FH4_76_80.npy : Generated Caption a woman is cutting a piece of dough
# a woman is cutting a piece of dough
#
# Video path C:\Users\User\Documents\P2M\test1\feature\Ms3QdGIzltU_1_16.npy : Generated Caption a hamster is eating seeds
# a hamster is eating seeds
#
# Video path C:\Users\User\Documents\P2M\test1\feature\nS6oQxX_Qi8_2_12.npy : Generated Caption a man is playing a trumpet
# a man is playing a trumpet
#
# Video path C:\Users\User\Documents\P2M\test1\feature\pDvzOLRLjPc_0_8.npy : Generated Caption a man is feeding a baby panda
# a man is feeding a baby panda
#
# Video path C:\Users\User\Documents\P2M\test1\feature\LQ-jv8g1YVI_1_6.npy : Generated Caption a cat is riding a roomba
# a cat is riding a roomba
#
# Video path C:\Users\User\Documents\P2M\test1\feature\kquB3rIgfGk_640_645.npy : Generated Caption a man is drinking water
# a man is drinking water
#
# Video path C:\Users\User\Documents\P2M\test1\feature\BVjvRpmHg0w_157_165.npy : Generated Caption a woman is cutting up a vegetable
# a woman is cutting up a vegetable
#
# Video path C:\Users\User\Documents\P2M\test1\feature\QzcTlEpAigQ_0_14.npy : Generated Caption a dog is playing with a ball
# a dog is playing with a ball
#
# Video path C:\Users\User\Documents\P2M\test1\feature\AysIdzGF-7M_6_14.npy : Generated Caption a kitten is playing with a toy
# a kitten is playing with a toy
#
# Video path C:\Users\User\Documents\P2M\test1\feature\iwpnUHFhjWc_9_14.npy : Generated Caption a woman is dancing
# a woman is dancing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\bJJndejsUWc_88_98.npy : Generated Caption a group of people are performing on stage
# a group of people are performing on stage
#
# Video path C:\Users\User\Documents\P2M\test1\feature\Xh6rdpJNaf0_0_15.npy : Generated Caption a rabbit is licking its face
# a rabbit is licking its face
#
# Video path C:\Users\User\Documents\P2M\test1\feature\nwk4m329bLw_2_10.npy : Generated Caption a man is riding a dogs
# a man is riding a dogs
#
# Video path C:\Users\User\Documents\P2M\test1\feature\ItFqogTmAvQ_389_395.npy : Generated Caption a man and a woman are running
# a man and a woman are running
#
# Video path C:\Users\User\Documents\P2M\test1\feature\PCXHuseKwDc_17_20.npy : Generated Caption a man is pouring antifreeze into a car
# a man is pouring antifreeze into a car
#
# Video path C:\Users\User\Documents\P2M\test1\feature\9Bxknsvy3jQ_53_58.npy : Generated Caption a man is riding a bicycle
# a man is riding a bicycle
#
# Video path C:\Users\User\Documents\P2M\test1\feature\a1Y73sPHKxw_0_5.npy : Generated Caption a chipmunk is walking
# a chipmunk is walking
#
# Video path C:\Users\User\Documents\P2M\test1\feature\C1MNCR1o9lU_0_7.npy : Generated Caption a woman is feeding a baby
# a woman is feeding a baby
#
# Video path C:\Users\User\Documents\P2M\test1\feature\zzit5b_-ukg_5_20.npy : Generated Caption a man is walking on a tree
# a man is walking on a tree
#
# Video path C:\Users\User\Documents\P2M\test1\feature\w9mqbwOIkVg_6_12.npy : Generated Caption a man is doing exercise
# a man is doing exercise
#
# Video path C:\Users\User\Documents\P2M\test1\feature\lAznAeFFldg_6_10.npy : Generated Caption a man is riding a bike
# a man is riding a bike
#
# Video path C:\Users\User\Documents\P2M\test1\feature\VF1K_6ZSOAY_23_28.npy : Generated Caption a woman is writing
# a woman is writing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\j2Dhf-xFUxU_13_20.npy : Generated Caption a woman is cutting a potato
# a woman is cutting a potato
#
# Video path C:\Users\User\Documents\P2M\test1\feature\_txL575S_OA_13_23.npy : Generated Caption a group of zebras are playing
# a group of zebras are playing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\E6sqA9QtV5I_195_201.npy : Generated Caption two people are kissing
# two people are kissing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\XzCcRzEa83U_1_8.npy : Generated Caption two men are fighting
# two men are fighting
#
# Video path C:\Users\User\Documents\P2M\test1\feature\8jP8CC2rKj4_80_88.npy : Generated Caption a dolphin is jumping out of the water
# a dolphin is jumping out of the water
#
# Video path C:\Users\User\Documents\P2M\test1\feature\HBCJYhUjVf0_0_9.npy : Generated Caption a lion is playing with a ball
# a lion is playing with a ball
#
# Video path C:\Users\User\Documents\P2M\test1\feature\n6U-TGahwvs_100_110.npy : Generated Caption a band is playing a guitar
# a band is playing a guitar
#
# Video path C:\Users\User\Documents\P2M\test1\feature\Uc63MFVwfrs_360_372.npy : Generated Caption a man is cutting a potato
# a man is cutting a potato
#
# Video path C:\Users\User\Documents\P2M\test1\feature\bQJQGoJF7_k_109_115.npy : Generated Caption a man is putting water into a plastic container
# a man is putting water into a plastic container
# Video path C:\Users\User\Documents\P2M\test1\feature\3SKyc0aKx70_46_52.npy : Generated Caption a man is doing a rope
# a man is doing a rope
#
# Video path C:\Users\User\Documents\P2M\test1\feature\6t0BpjwYKco_46_53.npy : Generated Caption a woman is peeling an apple
# a woman is peeling an apple
#
# Video path C:\Users\User\Documents\P2M\test1\feature\PuQVs2Ch1LY_5_15.npy : Generated Caption a girl is playing the flute
# a girl is playing the flute
#
# Video path C:\Users\User\Documents\P2M\test1\feature\elQqQfux7Po_12_22.npy : Generated Caption a dog is eating watermelon
# a dog is eating watermelon
#
# Video path C:\Users\User\Documents\P2M\test1\feature\zFIn8DeV5PM_20_33.npy : Generated Caption a man is playing a piano
# a man is playing a piano
#
# Video path C:\Users\User\Documents\P2M\test1\feature\dEn5E-TNezw_13_23.npy : Generated Caption a hedgehog is playing with a towel
# a hedgehog is playing with a towel
#
# Video path C:\Users\User\Documents\P2M\test1\feature\J3_hkgu6MGc_43_52.npy : Generated Caption a car is driving down the street
# a car is driving down the street
#
# Video path C:\Users\User\Documents\P2M\test1\feature\q9ew_nITQWY_54_62.npy : Generated Caption a man is playing soccer
# a man is playing soccer
#
# Video path C:\Users\User\Documents\P2M\test1\feature\6owu8Mow0_g_302_307.npy : Generated Caption a man is putting butter on a pizza
# a man is putting butter on a pizza
#
# Video path C:\Users\User\Documents\P2M\test1\feature\WTf5EgVY5uU_98_104.npy : Generated Caption a woman is cracking eggs into a bowl
# a woman is cracking eggs into a bowl
#
# Video path C:\Users\User\Documents\P2M\test1\feature\9W6aQNcU3PA_92_103.npy : Generated Caption a woman is filing her fingernails
# a woman is filing her fingernails
#
# Video path C:\Users\User\Documents\P2M\test1\feature\bXsKw3TOQXs_30_55.npy : Generated Caption a person is folding a piece of paper
# a person is folding a piece of paper
#
# Video path C:\Users\User\Documents\P2M\test1\feature\5W02895vT8c_312_322.npy : Generated Caption a plane is taking off
# a plane is taking off
#
# Video path C:\Users\User\Documents\P2M\test1\feature\PHDmVhShE80_20_29.npy : Generated Caption a woman is cutting a carrot
# a woman is cutting a carrot
#
# Video path C:\Users\User\Documents\P2M\test1\feature\6t0BpjwYKco_118_127.npy : Generated Caption a woman is frying onions
# a woman is frying onions
#
# Video path C:\Users\User\Documents\P2M\test1\feature\DIebwNHGjm8_133_148.npy : Generated Caption a woman is riding a boat
# a woman is riding a boat
#
# Video path C:\Users\User\Documents\P2M\test1\feature\39Ce7I6nXIw_96_104.npy : Generated Caption a man is walking on a horse
# a man is walking on a horse
#
# Video path C:\Users\User\Documents\P2M\test1\feature\0lh_UWF9ZP4_50_60.npy : Generated Caption a woman is mixing ingredients in a bowl
# a woman is mixing ingredients in a bowl
#
# Video path C:\Users\User\Documents\P2M\test1\feature\BVilbVCo9sU_1_11.npy : Generated Caption a cat is playing with a toy
# a cat is playing with a toy
#
# Video path C:\Users\User\Documents\P2M\test1\feature\OUII8_aOfNM_60_69.npy : Generated Caption a man is cutting meat
# a man is cutting meat
#
# Video path C:\Users\User\Documents\P2M\test1\feature\JK1R9k1WDpc_6_15.npy : Generated Caption elephants are running
# elephants are running
#
# Video path C:\Users\User\Documents\P2M\test1\feature\u4kMN1jamdM_10_20.npy : Generated Caption a woman is riding a horse
# a woman is riding a horse
#
# Video path C:\Users\User\Documents\P2M\test1\feature\7NNg0_n-bS8_21_30.npy : Generated Caption a man is playing a guitar
# a man is playing a guitar
#
# Video path C:\Users\User\Documents\P2M\test1\feature\UXs3eq68ZjE_255_260.npy : Generated Caption a man is pouring water into a pot
# a man is pouring water into a pot
#
# Video path C:\Users\User\Documents\P2M\test1\feature\-_hbPLsZvvo_288_305.npy : Generated Caption a woman is cutting a piece of meat
# a woman is cutting a piece of meat
#
# Video path C:\Users\User\Documents\P2M\test1\feature\wjH72cZ0GLM_1_10.npy : Generated Caption a man is pushing a car
# a man is pushing a car
#
# Video path C:\Users\User\Documents\P2M\test1\feature\32_A0-er4Ws_16_20.npy : Generated Caption a woman is peeling a tomato
# a woman is peeling a tomato
#
# Video path C:\Users\User\Documents\P2M\test1\feature\vE1gvaM3iAs_39_46.npy : Generated Caption a man is pouring a pitcher of water
# a man is pouring a pitcher of water
#
# Video path C:\Users\User\Documents\P2M\test1\feature\MF88IYF2MHY_25_59.npy : Generated Caption a kitten is playing
# a kitten is playing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\H7vezmDeZaw_2_7.npy : Generated Caption a man is running and falls down
# a man is running and falls down
#
# Video path C:\Users\User\Documents\P2M\test1\feature\BAf3LXFUaGs_28_38.npy : Generated Caption a man is playing drums
# a man is playing drums
#
# Video path C:\Users\User\Documents\P2M\test1\feature\80D0ylOqPJ8_0_5.npy : Generated Caption a dog is playing
# a dog is playing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\ywMLb2VfHbI_13_20.npy : Generated Caption a hedgehog is running
# a hedgehog is running
#
# Video path C:\Users\User\Documents\P2M\test1\feature\XZ0Ch_ClBfo_120_127.npy : Generated Caption a man is riding a beach
# a man is riding a beach
#
# Video path C:\Users\User\Documents\P2M\test1\feature\gMqKUPeTAkg_17_30.npy : Generated Caption a cat is drinking water
# a cat is drinking water
#
# Video path C:\Users\User\Documents\P2M\test1\feature\PmrTDZy3f2M_35_39.npy : Generated Caption two men are playing basketball
# two men are playing basketball
#
# Video path C:\Users\User\Documents\P2M\test1\feature\S-Civm_fbK8_20_26.npy : Generated Caption a man is kicking a soccer ball
# a man is kicking a soccer ball
#
# Video path C:\Users\User\Documents\P2M\test1\feature\BtQtRGI0F2Q_15_20.npy : Generated Caption a man is electrocuted
# a man is electrocuted
#
# Video path C:\Users\User\Documents\P2M\test1\feature\o_mWZWcm2r4_10_15.npy : Generated Caption a boy is climbing a rock wall
# a boy is climbing a rock wall
#
# Video path C:\Users\User\Documents\P2M\test1\feature\j2sOMdilDWU_87_97.npy : Generated Caption a man is drawing a piece of paper
# a man is drawing a piece of paper
#
# Video path C:\Users\User\Documents\P2M\test1\feature\hcCLIzzB1jQ_1_7.npy : Generated Caption a man is doing push-ups
# a man is doing push-ups
#
# Video path C:\Users\User\Documents\P2M\test1\feature\hJFBXHtxKIc_204_209.npy : Generated Caption a man is pouring sauce into a pot
# a man is pouring sauce into a pot
#
# Video path C:\Users\User\Documents\P2M\test1\feature\5K7Ru5s6YIw_8_11.npy : Generated Caption a kangaroo is eating
# a kangaroo is eating
#
# Video path C:\Users\User\Documents\P2M\test1\feature\-wa0umYJVGg_168_176.npy : Generated Caption a woman is cooking
# a woman is cooking
#
# Video path C:\Users\User\Documents\P2M\test1\feature\klteYv1Uv9A_27_33.npy : Generated Caption a man is riding a motorcycle
# a man is riding a motorcycle
#
# Video path C:\Users\User\Documents\P2M\test1\feature\swKrHEeOj9c_4_8.npy : Generated Caption a cat is meowing
# a cat is meowing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\qBFSt85-xqk_15_20.npy : Generated Caption a woman is pouring eggs into a bowl
# a woman is pouring eggs into a bowl
#
# Video path C:\Users\User\Documents\P2M\test1\feature\z9qbQX4J_2g_0_14.npy : Generated Caption a group of children are dancing
# a group of children are dancing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\AjZ-R3LFMzo_18_23.npy : Generated Caption a man is riding a motorcycle
# a man is riding a motorcycle
#
# Video path C:\Users\User\Documents\P2M\test1\feature\WPG-BIWOrG4_672_677.npy : Generated Caption a man is cutting a piece of meat
# a man is cutting a piece of meat
#
# Video path C:\Users\User\Documents\P2M\test1\feature\FWzsXeXCwuc_106_110.npy : Generated Caption monkeys are dancing
# monkeys are dancing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\WPG-BIWOrG4_683_689.npy : Generated Caption a man is cutting a fish
# a man is cutting a fish
#
# Video path C:\Users\User\Documents\P2M\test1\feature\m1NR0uNNs5Y_160_166.npy : Generated Caption a woman is cutting a vegetable
# a woman is cutting a vegetable
# Video path C:\Users\User\Documents\P2M\test1\feature\yC4eEuURH8c_19_28.npy : Generated Caption a cat is meowing
# a cat is meowing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\30GeJHYoerk_80_85.npy : Generated Caption a man is doing tricks with his feet
# a man is doing tricks with his feet
#
# Video path C:\Users\User\Documents\P2M\test1\feature\aRo8x3xXeEA_3_8.npy : Generated Caption a man is riding a skateboard
# a man is riding a skateboard
#
# Video path C:\Users\User\Documents\P2M\test1\feature\-rvjK0lE3z4_33_43.npy : Generated Caption a woman is cutting a potato
# a woman is cutting a potato
#
# Video path C:\Users\User\Documents\P2M\test1\feature\yyxtyCaEVqk_329_360.npy : Generated Caption a man is putting butter on a tortilla
# a man is putting butter on a tortilla
#
# Video path C:\Users\User\Documents\P2M\test1\feature\Q-soOsOLIGQ_0_22.npy : Generated Caption a man is playing with a tripod
# a man is playing with a tripod
#
# Video path C:\Users\User\Documents\P2M\test1\feature\msCidKHOh74_410_418.npy : Generated Caption a man is riding a motorcycle
# a man is riding a motorcycle
#
# Video path C:\Users\User\Documents\P2M\test1\feature\v-9Gx0gJmfo_91_99.npy : Generated Caption a woman is rowing a boat
# a woman is rowing a boat
#
# Video path C:\Users\User\Documents\P2M\test1\feature\8MVo7fje_oE_113_118.npy : Generated Caption a man is putting a microwave
# a man is putting a microwave
#
# Video path C:\Users\User\Documents\P2M\test1\feature\Lt1JijkvSKk_0_10.npy : Generated Caption a slow loris is playing
# a slow loris is playing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\_O9kWD8nuRU_25_35.npy : Generated Caption a woman is cutting a potato
# a woman is cutting a potato
#
# Video path C:\Users\User\Documents\P2M\test1\feature\oFUsn1owAbs_158_168.npy : Generated Caption a woman is dancing
# a woman is dancing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\Ea0thGZKPXA_25_35.npy : Generated Caption a girl is playing a flute
# a girl is playing a flute
#
# Video path C:\Users\User\Documents\P2M\test1\feature\lsanQj2yacs_102_108.npy : Generated Caption a woman is making a sandwich
# a woman is making a sandwich
#
# Video path C:\Users\User\Documents\P2M\test1\feature\OpR1Er5o6IY_209_217.npy : Generated Caption a man is cleaning a snake
# a man is cleaning a snake
#
# Video path C:\Users\User\Documents\P2M\test1\feature\IhwPQL9dFYc_61_75.npy : Generated Caption a woman is slicing a vegetable
# a woman is slicing a vegetable
#
# Video path C:\Users\User\Documents\P2M\test1\feature\kquB3rIgfGk_525_532.npy : Generated Caption a man is cutting a cucumber
# a man is cutting a cucumber
#
# Video path C:\Users\User\Documents\P2M\test1\feature\16iNk1hLJt4_37_40.npy : Generated Caption a group of people are racing down a track
# a group of people are racing down a track
#
# Video path C:\Users\User\Documents\P2M\test1\feature\ZdlG8fjGJlo_78_87.npy : Generated Caption a man is cutting a tomato
# a man is cutting a tomato
#
# Video path C:\Users\User\Documents\P2M\test1\feature\lfGlDg47How_361_367.npy : Generated Caption a man is mixing some food
# a man is mixing some food
#
# Video path C:\Users\User\Documents\P2M\test1\feature\c2a0GcoJAjw_107_129.npy : Generated Caption two women are dancing
# two women are dancing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\O06WXS_XZN0_0_6.npy : Generated Caption a man is playing with a dog
# a man is playing with a dog
#
# Video path C:\Users\User\Documents\P2M\test1\feature\47D9-U8hn5I_11_16.npy : Generated Caption a cat is walking on a table
# a cat is walking on a table
#
# Video path C:\Users\User\Documents\P2M\test1\feature\-_hbPLsZvvo_18_25.npy : Generated Caption a woman is cutting a cucumber
# a woman is cutting a cucumber
#
# Video path C:\Users\User\Documents\P2M\test1\feature\c51L6ZxZGjQ_137_154.npy : Generated Caption a woman is spreading butter on a bread
# a woman is spreading butter on a bread
#
# Video path C:\Users\User\Documents\P2M\test1\feature\-vKO3uSG6Do_3_14.npy : Generated Caption three women are dancing
# three women are dancing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\vfktGc_qx-w_2_18.npy : Generated Caption a man is riding a motorcycle
# a man is riding a motorcycle
#
# Video path C:\Users\User\Documents\P2M\test1\feature\zSPBC8EO6dY_122_126.npy : Generated Caption a man is shaking hands
# a man is shaking hands
#
# Video path C:\Users\User\Documents\P2M\test1\feature\s7znbqra118_91_97.npy : Generated Caption a group of people are marching on a road
# a group of people are marching on a road
#
# Video path C:\Users\User\Documents\P2M\test1\feature\Tied-t1fFsk_15_20.npy : Generated Caption a man is shooting a gun
# a man is shooting a gun
#
# Video path C:\Users\User\Documents\P2M\test1\feature\u9prcUCHlqM_73_80.npy : Generated Caption a man is shooting a gun
# a man is shooting a gun
#
# Video path C:\Users\User\Documents\P2M\test1\feature\aHiUM8uWxxo_17_25.npy : Generated Caption a man is shooting a man
# a man is shooting a man
#
# Video path C:\Users\User\Documents\P2M\test1\feature\mF6ijhSrbBQ_32_40.npy : Generated Caption a polar bear is walking on the snow
# a polar bear is walking on the snow
#
# Video path C:\Users\User\Documents\P2M\test1\feature\rw9h_574HxE_229_236.npy : Generated Caption a man and woman are walking
# a man and woman are walking
#
# Video path C:\Users\User\Documents\P2M\test1\feature\_WRC7HXBJpU_414_425.npy : Generated Caption a man is pouring water into a pan
# a man is pouring water into a pan
#
# Video path C:\Users\User\Documents\P2M\test1\feature\9OvXb1fot74_21_29.npy : Generated Caption women are dancing
# women are dancing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\vZa13vJugGU_0_30.npy : Generated Caption a man is playing a guitar with his feet
# a man is playing a guitar with his feet
#
# Video path C:\Users\User\Documents\P2M\test1\feature\r4qv_BNlQNk_93_98.npy : Generated Caption a man is eating a banana
# a man is eating a banana
#
# Video path C:\Users\User\Documents\P2M\test1\feature\dfOuTx66bJU_34_39.npy : Generated Caption a man is running
# a man is running
#
# Video path C:\Users\User\Documents\P2M\test1\feature\giLxPCgLLqg_9_19.npy : Generated Caption a man is catching a ball
# a man is catching a ball
#
# Video path C:\Users\User\Documents\P2M\test1\feature\e996zZ0uV_A_152_163.npy : Generated Caption a man is pouring a liquid into a plastic container
# a man is pouring a liquid into a plastic container
#
# Video path C:\Users\User\Documents\P2M\test1\feature\Ar70p1_LcfM_2_20.npy : Generated Caption a boy is playing a game on a laptop
# a boy is playing a game on a laptop
#
# Video path C:\Users\User\Documents\P2M\test1\feature\Kxa0mnDj0bs_113_124.npy : Generated Caption a polar bear is running on the snow
# a polar bear is running on the snow
#
# Video path C:\Users\User\Documents\P2M\test1\feature\ZlX_Gy4HP2E_38_55.npy : Generated Caption a woman is exercising
# a woman is exercising
#
# Video path C:\Users\User\Documents\P2M\test1\feature\fr9H1WLcF1A_326_336.npy : Generated Caption two boys are fighting
# two boys are fighting
#
# Video path C:\Users\User\Documents\P2M\test1\feature\GPyFZMJ5Dow_56_70.npy : Generated Caption a man is mixing flour
# a man is mixing flour
#
# Video path C:\Users\User\Documents\P2M\test1\feature\ZN2_czSBSD0_240_250.npy : Generated Caption a man is running
# a man is running
#
# Video path C:\Users\User\Documents\P2M\test1\feature\v7NpKUVqjpI_23_40.npy : Generated Caption an elephant is playing with a ball
# an elephant is playing with a ball
#
# Video path C:\Users\User\Documents\P2M\test1\feature\UbmZAe5u5FI_16_23.npy : Generated Caption a woman is cutting a green pepper
# a woman is cutting a green pepper
#
# Video path C:\Users\User\Documents\P2M\test1\feature\s1ZABV7AQdA_38_48.npy : Generated Caption a man is running down a road
# a man is running down a road
#
# Video path C:\Users\User\Documents\P2M\test1\feature\_7nP9z6T9m8_11_17.npy : Generated Caption a man is riding a bicycle
# a man is riding a bicycle
#
# Video path C:\Users\User\Documents\P2M\test1\feature\3ytUOoa1SBE_12_23.npy : Generated Caption people are dancing on stage
# people are dancing on stage
#
# Video path C:\Users\User\Documents\P2M\test1\feature\_o1UXSxTjfo_68_80.npy : Generated Caption a man is selling a man
# a man is selling a man
# Video path C:\Users\User\Documents\P2M\test1\feature\hW8TKz2Aea4_5_12.npy : Generated Caption a person is holding a hedgehog
# a person is holding a hedgehog
#
# Video path C:\Users\User\Documents\P2M\test1\feature\V6Fxclwdfxc_56_66.npy : Generated Caption a parrot is playing with a ball
# a parrot is playing with a ball
#
# Video path C:\Users\User\Documents\P2M\test1\feature\jlahRlo4jlU_30_36.npy : Generated Caption a man is walking down the road
# a man is walking down the road
#
# Video path C:\Users\User\Documents\P2M\test1\feature\QT8iCDc7NGU_18_23.npy : Generated Caption a woman is cleaning a freezer
# a woman is cleaning a freezer
#
# Video path C:\Users\User\Documents\P2M\test1\feature\p69d3UBdpR8_98_109.npy : Generated Caption a girl is applying makeup
# a girl is applying makeup
#
# Video path C:\Users\User\Documents\P2M\test1\feature\nBFhvrAOFqY_89_103.npy : Generated Caption a monkey is sitting off his head
# a monkey is sitting off his head
#
# Video path C:\Users\User\Documents\P2M\test1\feature\ysTmUTQ5wZE_17_45.npy : Generated Caption a baby panda is playing
# a baby panda is playing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\BtQEY2SL4g4_11_16.npy : Generated Caption a man is jumping
# a man is jumping
#
# Video path C:\Users\User\Documents\P2M\test1\feature\yfMTsYcLt10_0_7.npy : Generated Caption a man runs and falls down
# a man runs and falls down
#
# Video path C:\Users\User\Documents\P2M\test1\feature\6pcqRuFEMLs_46_52.npy : Generated Caption a man is jumping on a wall
# a man is jumping on a wall
#
# Video path C:\Users\User\Documents\P2M\test1\feature\cs33MNhpRNw_16_21.npy : Generated Caption a man is taking a door
# a man is taking a door
#
# Video path C:\Users\User\Documents\P2M\test1\feature\uqVCk2oDpSE_194_200.npy : Generated Caption a man is cutting a bun
# a man is cutting a bun
#
# Video path C:\Users\User\Documents\P2M\test1\feature\rwHT2SuNOi8_195_201.npy : Generated Caption a man is putting bacon on a piece of bacon
# a man is putting bacon on a piece of bacon
#
# Video path C:\Users\User\Documents\P2M\test1\feature\q3I3R_gqy8M_73_79.npy : Generated Caption a man is crying
# a man is crying
#
# Video path C:\Users\User\Documents\P2M\test1\feature\6sKdTbRkahM_6_12.npy : Generated Caption a man is cutting a pineapple
# a man is cutting a pineapple
#
# Video path C:\Users\User\Documents\P2M\test1\feature\ifS2nXfCyYo_4_34.npy : Generated Caption a guinea pig is eating a carrot
# a guinea pig is eating a carrot
#
# Video path C:\Users\User\Documents\P2M\test1\feature\HPFLN5azwtA_56_63.npy : Generated Caption a badger is digging a hole
# a badger is digging a hole
#
# Video path C:\Users\User\Documents\P2M\test1\feature\YXixZrSxefk_6_15.npy : Generated Caption a man is cutting a potato
# a man is cutting a potato
#
# Video path C:\Users\User\Documents\P2M\test1\feature\73vUksucPz8_12_20.npy : Generated Caption a woman is playing a violin
# a woman is playing a violin
#
# Video path C:\Users\User\Documents\P2M\test1\feature\CBD9h0jUq3w_1_7.npy : Generated Caption a man is playing soccer
# a man is playing soccer
#
# Video path C:\Users\User\Documents\P2M\test1\feature\_6OTzzK7t9Y_158_170.npy : Generated Caption a man is playing piano
# a man is playing piano
#
# Video path C:\Users\User\Documents\P2M\test1\feature\Je3V7U5Ctj4_582_587.npy : Generated Caption a man is sprinkling cheese on a tortilla
# a man is sprinkling cheese on a tortilla
#
# Video path C:\Users\User\Documents\P2M\test1\feature\CHVhwcOg6y8_1_12.npy : Generated Caption a man is playing with a toy
# a man is playing with a toy
#
# Video path C:\Users\User\Documents\P2M\test1\feature\J4otiwOjQy8_98_112.npy : Generated Caption a man is slicing a knife
# a man is slicing a knife
#
# Video path C:\Users\User\Documents\P2M\test1\feature\_WRC7HXBJpU_386_391.npy : Generated Caption a man is pouring oil into a pan
# a man is pouring oil into a pan
#
# Video path C:\Users\User\Documents\P2M\test1\feature\EdrZtaBUXIo_25_29.npy : Generated Caption a wombat is emitting
# a wombat is emitting
#
# Video path C:\Users\User\Documents\P2M\test1\feature\5XxshEdcfAM_85_100.npy : Generated Caption a man is dancing
# a man is dancing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\ACOmKiJDkA4_161_170.npy : Generated Caption a woman is peeling a shrimp
# a woman is peeling a shrimp
#
# Video path C:\Users\User\Documents\P2M\test1\feature\RSx5G0_xH48_12_17.npy : Generated Caption a dog is barking
# a dog is barking
#
# Video path C:\Users\User\Documents\P2M\test1\feature\AEKPjVHSVZc_0_12.npy : Generated Caption people are dancing
# people are dancing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\00jrXRMlZOY_0_10.npy : Generated Caption a person is holding a toad
# a person is holding a toad
#
# Video path C:\Users\User\Documents\P2M\test1\feature\0hyZ__3YhZc_485_490.npy : Generated Caption a man is pouring some vegetables in a pot
# a man is pouring some vegetables in a pot
#
# Video path C:\Users\User\Documents\P2M\test1\feature\zpgW7m7_LZw_2_15.npy : Generated Caption a boy is playing golf
# a boy is playing golf
#
# Video path C:\Users\User\Documents\P2M\test1\feature\bQJQGoJF7_k_120_126.npy : Generated Caption a man is pouring sauce into a bowl
# a man is pouring sauce into a bowl
#
# Video path C:\Users\User\Documents\P2M\test1\feature\ghynaoVNwZc_1_20.npy : Generated Caption a car is driving
# a car is driving
#
# Video path C:\Users\User\Documents\P2M\test1\feature\1rECrfrdNTo_200_207.npy : Generated Caption a woman is pouring a tomato into a pan
# a woman is pouring a tomato into a pan
#
# Video path C:\Users\User\Documents\P2M\test1\feature\8PQiaurIiDM_94_99.npy : Generated Caption a man is cutting a sword with a sword
# a man is cutting a sword with a sword
#
# Video path C:\Users\User\Documents\P2M\test1\feature\4s_0-zIWEog_1_15.npy : Generated Caption a man is eating
# a man is eating
#
# Video path C:\Users\User\Documents\P2M\test1\feature\dJEoDaA6VXc_1_19.npy : Generated Caption a man is riding a horse
# a man is riding a horse
#
# Video path C:\Users\User\Documents\P2M\test1\feature\ZxqkAGNyo8A_12_22.npy : Generated Caption a girl is playing a piano
# a girl is playing a piano
#
# Video path C:\Users\User\Documents\P2M\test1\feature\crfrKqFp0Zg_15_25.npy : Generated Caption a man is playing a flute
# a man is playing a flute
#
# Video path C:\Users\User\Documents\P2M\test1\feature\Pr5LQq42l4M_12_17.npy : Generated Caption a man is jumping on the roof of a building
# a man is jumping on the roof of a building
#
# Video path C:\Users\User\Documents\P2M\test1\feature\wNv74rvkAw8_30_40.npy : Generated Caption the kittens are eating
# the kittens are eating
#
# Video path C:\Users\User\Documents\P2M\test1\feature\c75SIlAjfjg_6_14.npy : Generated Caption a group of kids are dancing on stage
# a group of kids are dancing on stage
#
# Video path C:\Users\User\Documents\P2M\test1\feature\_SNE2MYAotU_41_49.npy : Generated Caption a woman is scratching a baby
# a woman is scratching a baby
#
# Video path C:\Users\User\Documents\P2M\test1\feature\jjl2ZMdFCsw_130_142.npy : Generated Caption a man is doing a sword
# a man is doing a sword
#
# Video path C:\Users\User\Documents\P2M\test1\feature\HqbVbPvlDoM_0_11.npy : Generated Caption a woman is doing push-ups with a dog
# a woman is doing push-ups with a dog
#
# Video path C:\Users\User\Documents\P2M\test1\feature\q8t7iSGAKik_11_31.npy : Generated Caption a man is kicking a soccer ball
# a man is kicking a soccer ball
#
# Video path C:\Users\User\Documents\P2M\test1\feature\4QdX5Q3qQsQ_6_14.npy : Generated Caption a man is talking to his hands
# a man is talking to his hands
#
# Video path C:\Users\User\Documents\P2M\test1\feature\R3a9r8qFlhQ_0_12.npy : Generated Caption a man is cutting a snake
# a man is cutting a snake
#
# Video path C:\Users\User\Documents\P2M\test1\feature\SzEbtbNSg04_111_117.npy : Generated Caption a woman is pouring water into a pot
# a woman is pouring water into a pot
#
# Video path C:\Users\User\Documents\P2M\test1\feature\MJoxGpEswOI_9_16.npy : Generated Caption a basketball player is playing basketball
# a basketball player is playing basketball
#
# Video path C:\Users\User\Documents\P2M\test1\feature\ngHDYzhDBk4_5_14.npy : Generated Caption a group of girls are dancing
# a group of girls are dancing
# Video path C:\Users\User\Documents\P2M\test1\feature\6t0BpjwYKco_53_59.npy : Generated Caption a woman is cutting a potato
# a woman is cutting a potato
#
# Video path C:\Users\User\Documents\P2M\test1\feature\KPPCwmU5OHQ_480_486.npy : Generated Caption a person is stirring a pot of chili
# a person is stirring a pot of chili
#
# Video path C:\Users\User\Documents\P2M\test1\feature\V--abChiVVc_30_40.npy : Generated Caption a man is dancing
# a man is dancing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\nBJV56WUDng_38_47.npy : Generated Caption a man is cutting a banana
# a man is cutting a banana
#
# Video path C:\Users\User\Documents\P2M\test1\feature\77iDIp40m9E_3_9.npy : Generated Caption a dog is running on the ground
# a dog is running on the ground
#
# Video path C:\Users\User\Documents\P2M\test1\feature\qhknaG9ifbs_122_127.npy : Generated Caption a man is playing with a sword
# a man is playing with a sword
#
# Video path C:\Users\User\Documents\P2M\test1\feature\hNECyt6Bo0A_5_10.npy : Generated Caption two men are dancing
# two men are dancing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\sWqi41wyXcQ_68_79.npy : Generated Caption a man is doing exercise
# a man is doing exercise
#
# Video path C:\Users\User\Documents\P2M\test1\feature\_QJbjKkfdcs_52_57.npy : Generated Caption a man is playing a violin
# a man is playing a violin
#
# Video path C:\Users\User\Documents\P2M\test1\feature\iCiGjZEV7VI_65_75.npy : Generated Caption a woman is applying makeup
# a woman is applying makeup
#
# Video path C:\Users\User\Documents\P2M\test1\feature\ywHBKayhyvQ_19_28.npy : Generated Caption a boy is walking on a bridge
# a boy is walking on a bridge
#
# Video path C:\Users\User\Documents\P2M\test1\feature\0NPtAv3_uVI_46_54.npy : Generated Caption a woman is riding a boat
# a woman is riding a boat
#
# Video path C:\Users\User\Documents\P2M\test1\feature\ZsrPKtx0qyg_7_15.npy : Generated Caption a dog is playing with a dog
# a dog is playing with a dog
#
# Video path C:\Users\User\Documents\P2M\test1\feature\X7sQq-Iu1gQ_12_22.npy : Generated Caption a man is singing
# a man is singing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\HJHPB_Y8GZE_22_28.npy : Generated Caption a dog is playing
# a dog is playing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\_6OTzzK7t9Y_73_78.npy : Generated Caption a woman is mixing flour
# a woman is mixing flour
#
# Video path C:\Users\User\Documents\P2M\test1\feature\MJNStEgDKXU_3_10.npy : Generated Caption a dog is barking
# a dog is barking
#
# Video path C:\Users\User\Documents\P2M\test1\feature\4ge5_V-xhP0_138_142.npy : Generated Caption a man is playing with a large box
# a man is playing with a large box
#
# Video path C:\Users\User\Documents\P2M\test1\feature\L9wD3kw-8FE_65_73.npy : Generated Caption a man is chopping a tree
# a man is chopping a tree
#
# Video path C:\Users\User\Documents\P2M\test1\feature\X_NLV2KCnIE_60_70.npy : Generated Caption a car is moving
# a car is moving
#
# Video path C:\Users\User\Documents\P2M\test1\feature\o2X6UCaNqKA_27_36.npy : Generated Caption a man is shooting a gun
# a man is shooting a gun
#
# Video path C:\Users\User\Documents\P2M\test1\feature\qeKX-N1nKiM_106_115.npy : Generated Caption a woman is mixing flour and water
# a woman is mixing flour and water
#
# Video path C:\Users\User\Documents\P2M\test1\feature\ACOmKiJDkA4_121_128.npy : Generated Caption a woman is frying some meat
# a woman is frying some meat
#
# Video path C:\Users\User\Documents\P2M\test1\feature\zMg9dChF97A_12_38.npy : Generated Caption a man is cutting a potato
# a man is cutting a potato
#
# Video path C:\Users\User\Documents\P2M\test1\feature\_yUiusXxfWI_150_165.npy : Generated Caption a man is putting a fire
# a man is putting a fire
#
# Video path C:\Users\User\Documents\P2M\test1\feature\FH8vgAp4VDU_10_14.npy : Generated Caption a man is walking down the stairs
# a man is walking down the stairs
#
# Video path C:\Users\User\Documents\P2M\test1\feature\53dc4z7HLyg_25_29.npy : Generated Caption a man is doing a skateboard
# a man is doing a skateboard
#
# Video path C:\Users\User\Documents\P2M\test1\feature\0hyZ__3YhZc_410_417.npy : Generated Caption a man is pouring some vegetables into a pan
# a man is pouring some vegetables into a pan
#
# Video path C:\Users\User\Documents\P2M\test1\feature\XtQdAPV2UZs_4_11.npy : Generated Caption a man is lifting a car
# a man is lifting a car
#
# Video path C:\Users\User\Documents\P2M\test1\feature\J7zb8YXrmIA_93_99.npy : Generated Caption a man is riding a bicycle
# a man is riding a bicycle
#
# Video path C:\Users\User\Documents\P2M\test1\feature\C_1cnNdMwxY_0_8.npy : Generated Caption a man is playing with a dog
# a man is playing with a dog
#
# Video path C:\Users\User\Documents\P2M\test1\feature\kWLNZzuo3do_31_37.npy : Generated Caption a woman is cutting a piece of paper
# a woman is cutting a piece of paper
#
# Video path C:\Users\User\Documents\P2M\test1\feature\WrsS6X-FB-I_30_47.npy : Generated Caption a man is slicing a bread
# a man is slicing a bread
#
# Video path C:\Users\User\Documents\P2M\test1\feature\VfqlfprZsaQ_75_85.npy : Generated Caption three women are dancing
# three women are dancing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\2G9fkvBzzQE_10_20.npy : Generated Caption a man is talking
# a man is talking
#
# Video path C:\Users\User\Documents\P2M\test1\feature\4lXdVS697DQ_10_25.npy : Generated Caption a man is riding a boat
# a man is riding a boat
#
# Video path C:\Users\User\Documents\P2M\test1\feature\7uOiiA4Kxbo_23_35.npy : Generated Caption a man is riding a bicycle
# a man is riding a bicycle
#
# Video path C:\Users\User\Documents\P2M\test1\feature\GcfWD62sbcs_13_33.npy : Generated Caption a squirrel is walking on a tree
# a squirrel is walking on a tree
#
# Video path C:\Users\User\Documents\P2M\test1\feature\XdB0pVjFYoU_1_8.npy : Generated Caption a man is holding a monkey
# a man is holding a monkey
#
# Video path C:\Users\User\Documents\P2M\test1\feature\QOmrchUPnBs_10_20.npy : Generated Caption a man is playing a flute
# a man is playing a flute
#
# Video path C:\Users\User\Documents\P2M\test1\feature\edqyq4Q-7uU_103_109.npy : Generated Caption a man is dancing
# a man is dancing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\xxHx6s_DbUo_32_36.npy : Generated Caption a man is running
# a man is running
#
# Video path C:\Users\User\Documents\P2M\test1\feature\BnJUWwSx1kE_11_22.npy : Generated Caption a wombat is walking
# a wombat is walking
#
# Video path C:\Users\User\Documents\P2M\test1\feature\nd0ToNwccl4_12_17.npy : Generated Caption a man is kicking a soccer ball
# a man is kicking a soccer ball
#
# Video path C:\Users\User\Documents\P2M\test1\feature\ggic669elLM_200_215.npy : Generated Caption a man is dancing
# a man is dancing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\JXSkYkiKO0I_42_46.npy : Generated Caption a man is doing push-ups
# a man is doing push-ups
#
# Video path C:\Users\User\Documents\P2M\test1\feature\6t0BpjwYKco_71_76.npy : Generated Caption a woman is peeling a potato
# a woman is peeling a potato
#
# Video path C:\Users\User\Documents\P2M\test1\feature\ao-9B8IV9_E_175_187.npy : Generated Caption a boy is falling down a house
# a boy is falling down a house
#
# Video path C:\Users\User\Documents\P2M\test1\feature\KPPCwmU5OHQ_227_238.npy : Generated Caption a man is pouring oil into a pot
# a man is pouring oil into a pot
#
# Video path C:\Users\User\Documents\P2M\test1\feature\fX5G_JwPlLo_640_660.npy : Generated Caption a man is opening a box
# a man is opening a box
#
# Video path C:\Users\User\Documents\P2M\test1\feature\cFzSEIGrEfA_0_24.npy : Generated Caption a man is cutting a fish
# a man is cutting a fish
#
# Video path C:\Users\User\Documents\P2M\test1\feature\Ayh26v6Nies_17_22.npy : Generated Caption two dogs are playing
# two dogs are playing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\Y4BeJ-64294_20_30.npy : Generated Caption a man is shooting a gun
# a man is shooting a gun
#
# Video path C:\Users\User\Documents\P2M\test1\feature\Qtu-PXuvCx4_12_17.npy : Generated Caption a baby is eating a chocolate
# a baby is eating a chocolate
#
# Video path C:\Users\User\Documents\P2M\test1\feature\-DKuLXYoY3g_14_20.npy : Generated Caption a boy is dribbling a basketball
# a boy is dribbling a basketball
# Video path C:\Users\User\Documents\P2M\test1\feature\_0nX-El-ySo_83_93.npy : Generated Caption a man is cutting a paper
# a man is cutting a paper
#
# Video path C:\Users\User\Documents\P2M\test1\feature\IhwPQL9dFYc_124_129.npy : Generated Caption a woman is cutting a carrot
# a woman is cutting a carrot
#
# Video path C:\Users\User\Documents\P2M\test1\feature\D2FbgK_kkE8_121_151.npy : Generated Caption a woman is cutting a pineapple
# a woman is cutting a pineapple
#
# Video path C:\Users\User\Documents\P2M\test1\feature\BIqVvRh_cEY_143_149.npy : Generated Caption a boy is running
# a boy is running
#
# Video path C:\Users\User\Documents\P2M\test1\feature\GWQTAe64m-0_91_94.npy : Generated Caption a man is dancing
# a man is dancing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\TwQzFqBqgeA_0_10.npy : Generated Caption a man is sitting on the beach
# a man is sitting on the beach
#
# Video path C:\Users\User\Documents\P2M\test1\feature\qPXynwa_2iM_15_25.npy : Generated Caption a dog is running
# a dog is running
#
# Video path C:\Users\User\Documents\P2M\test1\feature\d_BWuttLRFM_42_52.npy : Generated Caption a boy is playing a flute
# a boy is playing a flute
#
# Video path C:\Users\User\Documents\P2M\test1\feature\Lw0eGsYxElA_11_14.npy : Generated Caption a man is doing a stick
# a man is doing a stick
#
# Video path C:\Users\User\Documents\P2M\test1\feature\WTf5EgVY5uU_58_76.npy : Generated Caption a woman is cutting a potato
# a woman is cutting a potato
#
# Video path C:\Users\User\Documents\P2M\test1\feature\PHDmVhShE80_78_82.npy : Generated Caption a woman is cracking eggs into a bowl
# a woman is cracking eggs into a bowl
#
# Video path C:\Users\User\Documents\P2M\test1\feature\HZqscSWtHmo_24_34.npy : Generated Caption a man is singing
# a man is singing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\98shpdib9sg_55_62.npy : Generated Caption a boy is playing with a ball
# a boy is playing with a ball
#
# Video path C:\Users\User\Documents\P2M\test1\feature\iuqVpMdb1NM_35_43.npy : Generated Caption a woman is folding a piece of paper
# a woman is folding a piece of paper
#
# Video path C:\Users\User\Documents\P2M\test1\feature\F44bLc6t7-I_1_8.npy : Generated Caption a man is serving a human serving
# a man is serving a human serving
#
# Video path C:\Users\User\Documents\P2M\test1\feature\QGgJlHi3tjw_1_15.npy : Generated Caption a man is talking on a podium
# a man is talking on a podium
#
# Video path C:\Users\User\Documents\P2M\test1\feature\e-j59PqJjSM_264_277.npy : Generated Caption a man is cutting a tomato
# a man is cutting a tomato
#
# Video path C:\Users\User\Documents\P2M\test1\feature\W8l_ezoU8Lc_55_70.npy : Generated Caption a man is playing a guitar
# a man is playing a guitar
#
# Video path C:\Users\User\Documents\P2M\test1\feature\2YhDTpzxd3c_149_154.npy : Generated Caption a woman is singing and a man
# a woman is singing and a man
#
# Video path C:\Users\User\Documents\P2M\test1\feature\uH8ObB_dyOk_159_166.npy : Generated Caption two women are shopping
# two women are shopping
#
# Video path C:\Users\User\Documents\P2M\test1\feature\qNjeEx92rTA_281_299.npy : Generated Caption a man is mixing flour in a bowl
# a man is mixing flour in a bowl
#
# Video path C:\Users\User\Documents\P2M\test1\feature\QHkvBU8diwU_1_18.npy : Generated Caption a man is playing a guitar
# a man is playing a guitar
#
# Video path C:\Users\User\Documents\P2M\test1\feature\7_XASfcYdBk_3_13.npy : Generated Caption a man is playing a guitar
# a man is playing a guitar
#
# Video path C:\Users\User\Documents\P2M\test1\feature\RWWvWFeE6_Q_2_26.npy : Generated Caption a man is pushing a car
# a man is pushing a car
#
# Video path C:\Users\User\Documents\P2M\test1\feature\hNOzHvsEmg4_31_36.npy : Generated Caption a soccer player is hitting the goal
# a soccer player is hitting the goal
#
# Video path C:\Users\User\Documents\P2M\test1\feature\ArEWo8pERFc_17_21.npy : Generated Caption a woman is sitting on bed
# a woman is sitting on bed
#
# Video path C:\Users\User\Documents\P2M\test1\feature\WTf5EgVY5uU_66_75.npy : Generated Caption a woman is slicing a potato
# a woman is slicing a potato
#
# Video path C:\Users\User\Documents\P2M\test1\feature\VZ6H73nH7xs_27_33.npy : Generated Caption a man is doing exercise
# a man is doing exercise
#
# Video path C:\Users\User\Documents\P2M\test1\feature\kNHivduxQWg_0_14.npy : Generated Caption two pigs are eating
# two pigs are eating
#
# Video path C:\Users\User\Documents\P2M\test1\feature\qeKX-N1nKiM_68_72.npy : Generated Caption a woman is cutting a potato
# a woman is cutting a potato
#
# Video path C:\Users\User\Documents\P2M\test1\feature\9Wr48VFhZH8_45_50.npy : Generated Caption a tiger is playing with a man
# a tiger is playing with a man
#
# Video path C:\Users\User\Documents\P2M\test1\feature\n_Z0-giaspE_270_278.npy : Generated Caption a man is driving a helicopter
# a man is driving a helicopter
#
# Video path C:\Users\User\Documents\P2M\test1\feature\_KMoC6ZdeXs_10_16.npy : Generated Caption a man is playing a guitar
# a man is playing a guitar
#
# Video path C:\Users\User\Documents\P2M\test1\feature\hJuqBDw_TT4_105_112.npy : Generated Caption two women are dancing
# two women are dancing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\9HTUcMjWB3g_134_138.npy : Generated Caption a woman is slicing a pepper
# a woman is slicing a pepper
#
# Video path C:\Users\User\Documents\P2M\test1\feature\De815YpTBic_41_48.npy : Generated Caption a car is driving down
# a car is driving down
#
# Video path C:\Users\User\Documents\P2M\test1\feature\0hyZ__3YhZc_418_424.npy : Generated Caption a man is pouring some sauce into a pan
# a man is pouring some sauce into a pan
#
# Video path C:\Users\User\Documents\P2M\test1\feature\kEGmZDpZ_RE_248_293.npy : Generated Caption a woman is cutting a vegetable
# a woman is cutting a vegetable
#
# Video path C:\Users\User\Documents\P2M\test1\feature\sJC7E06IBXI_49_59.npy : Generated Caption a car is driving down a road
# a car is driving down a road
#
# Video path C:\Users\User\Documents\P2M\test1\feature\-FugkxLmGO4_5_16.npy : Generated Caption a dog is barking
# a dog is barking
#
# Video path C:\Users\User\Documents\P2M\test1\feature\zfQOH4UGU_I_1_10.npy : Generated Caption a dog is barking
# a dog is barking
#
# Video path C:\Users\User\Documents\P2M\test1\feature\urNX3e1Wbc8_30_38.npy : Generated Caption a dog is playing with a dog
# a dog is playing with a dog
#
# Video path C:\Users\User\Documents\P2M\test1\feature\77iDIp40m9E_119_123.npy : Generated Caption a little girl is walking on the road
# a little girl is walking on the road
#
# Video path C:\Users\User\Documents\P2M\test1\feature\kWLNZzuo3do_251_260.npy : Generated Caption a woman is frying some food
# a woman is frying some food
#
# Video path C:\Users\User\Documents\P2M\test1\feature\5W02895vT8c_460_470.npy : Generated Caption a plane is landing
# a plane is landing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\vz71JKcpeUU_0_10.npy : Generated Caption a plane is landing
# a plane is landing
#
# ...
# a boy is playing with a dog
#
# Video path C:\Users\User\Documents\P2M\test1\feature\ecm9gf2Pgkc_1_24.npy : Generated Caption a woman is playing with a rabbit
# a woman is playing with a rabbit
#
# Video path C:\Users\User\Documents\P2M\test1\feature\-_hbPLsZvvo_211_219.npy : Generated Caption a woman is frying a pan
# a woman is frying a pan
#
# Video path C:\Users\User\Documents\P2M\test1\feature\dtn0PuxgfkM_0_5.npy : Generated Caption a man is running
# a man is running
#
# Video path C:\Users\User\Documents\P2M\test1\feature\zbAk0gX7kas_16_24.npy : Generated Caption a baby is sucking a baby
# a baby is sucking a baby
#
# Video path C:\Users\User\Documents\P2M\test1\feature\HV12kTtdTT4_5_14.npy : Generated Caption a cat is watching television
# a cat is watching television
#
# Video path C:\Users\User\Documents\P2M\test1\feature\TjLCJKoot4U_43_65.npy : Generated Caption a lion is running
# a lion is running
#
# Video path C:\Users\User\Documents\P2M\test1\feature\x_7BrCQdVUs_172_177.npy : Generated Caption a woman is waking up a man
# a woman is waking up a man
#
# Video path C:\Users\User\Documents\P2M\test1\feature\HO_ovIrLWfQ_1_11.npy : Generated Caption a man is rowing a boat
# a man is rowing a boat
#
# Video path C:\Users\User\Documents\P2M\test1\feature\YwmUgVrUJ4I_0_15.npy : Generated Caption a woman is exercising
# a woman is exercising
#
# Video path C:\Users\User\Documents\P2M\test1\feature\yId1rg5-ac0_40_50.npy : Generated Caption two women are wrestling
# two women are wrestling
#
# Video path C:\Users\User\Documents\P2M\test1\feature\4zPSShqsq-o_3_16.npy : Generated Caption a baby is laughing
# a baby is laughing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\W1052h2rzoA_91_98.npy : Generated Caption two men are dancing on stage
# two men are dancing on stage
#
# Video path C:\Users\User\Documents\P2M\test1\feature\EXyp0Q7L1zE_30_38.npy : Generated Caption a woman is dancing
# a woman is dancing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\OO-5-eVEKPA_25_31.npy : Generated Caption a girl is playing a piano
# a girl is playing a piano
#
# Video path C:\Users\User\Documents\P2M\test1\feature\q-JHcsqJXWY_0_8.npy : Generated Caption a panda is playing
# a panda is playing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\5E66Gk3V1Bc_23_30.npy : Generated Caption a monkey is walking
# a monkey is walking
#
# Video path C:\Users\User\Documents\P2M\test1\feature\05gNigkqfNU_11_23.npy : Generated Caption a woman is peeling a potato
# a woman is peeling a potato
#
# Video path C:\Users\User\Documents\P2M\test1\feature\kWLNZzuo3do_76_80.npy : Generated Caption a woman is cutting a piece of meat
# a woman is cutting a piece of meat
#
# Video path C:\Users\User\Documents\P2M\test1\feature\05Gtb7_9tLU_0_9.npy : Generated Caption a group of people are riding a bike
# a group of people are riding a bike
#
# Video path C:\Users\User\Documents\P2M\test1\feature\5XxshEdcfAM_96_107.npy : Generated Caption a man is dancing
# a man is dancing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\PTxHJMM6hHE_0_15.npy : Generated Caption a boy is playing a game of a boy
# a boy is playing a game of a boy
#
# Video path C:\Users\User\Documents\P2M\test1\feature\gIvetX_oXeI_85_90.npy : Generated Caption a man is doing exercise
# a man is doing exercise
#
# Video path C:\Users\User\Documents\P2M\test1\feature\TZ860P4iTaM_11_20.npy : Generated Caption a cat is playing a piano
# a cat is playing a piano
#
# Video path C:\Users\User\Documents\P2M\test1\feature\3doK4FQM5-k_46_57.npy : Generated Caption a man is filling a pan with water
# a man is filling a pan with water
#
# Video path C:\Users\User\Documents\P2M\test1\feature\hM3jzlyNIpc_0_10.npy : Generated Caption a hamster is running on a wheel
# a hamster is running on a wheel
#
# Video path C:\Users\User\Documents\P2M\test1\feature\yvfhk1kwKls_103_113.npy : Generated Caption a woman is dancing
# a woman is dancing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\l57mQZvDaL4_10_30.npy : Generated Caption a cat is playing with a dog
# a cat is playing with a dog
#
# Video path C:\Users\User\Documents\P2M\test1\feature\aA05I5QaZnM_66_75.npy : Generated Caption a woman is brushing her hair
# a woman is brushing her hair
#
# Video path C:\Users\User\Documents\P2M\test1\feature\0lh_UWF9ZP4_138_145.npy : Generated Caption a woman is cutting a carrot
# a woman is cutting a carrot
#
# Video path C:\Users\User\Documents\P2M\test1\feature\dc4UltkRJsw_53_59.npy : Generated Caption a boy is walking down the road
# a boy is walking down the road
#
# Video path C:\Users\User\Documents\P2M\test1\feature\k8l4ETsylVY_9_18.npy : Generated Caption a dog is swimming in the water
# a dog is swimming in the water
# Video path C:\Users\User\Documents\P2M\test1\feature\8PQiaurIiDM_247_255.npy : Generated Caption a man is cutting a sword
# a man is cutting a sword
#
# Video path C:\Users\User\Documents\P2M\test1\feature\QTAqjSbMkXU_65_75.npy : Generated Caption a woman is putting some meat
# a woman is putting some meat
#
# Video path C:\Users\User\Documents\P2M\test1\feature\-mAoVOhKy0c_4_9.npy : Generated Caption a train is moving on a track
# a train is moving on a track
#
# Video path C:\Users\User\Documents\P2M\test1\feature\Z3rj9LbCOaM_0_12.npy : Generated Caption two baby otters are playing in the water
# two baby otters are playing in the water
#
# Video path C:\Users\User\Documents\P2M\test1\feature\E4k0Aylzdyo_97_104.npy : Generated Caption a girl is riding a motorcycle
# a girl is riding a motorcycle
#
# Video path C:\Users\User\Documents\P2M\test1\feature\D1X6qXkLjYE_41_49.npy : Generated Caption a man is dancing
# a man is dancing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\UbmZAe5u5FI_88_98.npy : Generated Caption a woman is cutting a fish
# a woman is cutting a fish
#
# Video path C:\Users\User\Documents\P2M\test1\feature\vub04F8CWng_32_41.npy : Generated Caption two zebras are playing
# two zebras are playing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\LjimLwAhAOQ_5_15.npy : Generated Caption two girls are talking on the phone
# two girls are talking on the phone
#
# Video path C:\Users\User\Documents\P2M\test1\feature\bqMmyY1ImkI_0_14.npy : Generated Caption three boys are playing in a pool
# three boys are playing in a pool
#
# Video path C:\Users\User\Documents\P2M\test1\feature\9d57lHEsLU8_1_14.npy : Generated Caption a frog is jumping out of water
# a frog is jumping out of water
#
# Video path C:\Users\User\Documents\P2M\test1\feature\2LgrGHWSy6k_122_135.npy : Generated Caption a woman is drinking
# a woman is drinking
#
# Video path C:\Users\User\Documents\P2M\test1\feature\d4AGWnHJcaY_6_19.npy : Generated Caption a hamster is eating
# a hamster is eating
#
# Video path C:\Users\User\Documents\P2M\test1\feature\RjpbFlOHFps_8_25.npy : Generated Caption a group of people are moving through the road
# a group of people are moving through the road
#
# Video path C:\Users\User\Documents\P2M\test1\feature\rw9h_574HxE_161_166.npy : Generated Caption a woman is dancing
# a woman is dancing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\4_WZN7uW0NY_140_145.npy : Generated Caption two men are sweeping a house
# two men are sweeping a house
#
# Video path C:\Users\User\Documents\P2M\test1\feature\0lh_UWF9ZP4_199_207.npy : Generated Caption a woman is cutting a piece of meat
# a woman is cutting a piece of meat
#
# Video path C:\Users\User\Documents\P2M\test1\feature\3zgEl-OLFKE_12_15.npy : Generated Caption a dog is running up a stairs
# a dog is running up a stairs
#
# Video path C:\Users\User\Documents\P2M\test1\feature\Gn4Iv5ARIXc_83_93.npy : Generated Caption a man is shooting
# a man is shooting
#
# Video path C:\Users\User\Documents\P2M\test1\feature\kKGehSw5ht8_39_45.npy : Generated Caption a man is talking
# a man is talking
#
# Video path C:\Users\User\Documents\P2M\test1\feature\hbE29pZh76I_3_8.npy : Generated Caption a basketball player is hitting a basketball
# a basketball player is hitting a basketball
#
# Video path C:\Users\User\Documents\P2M\test1\feature\uB9zRlV47qA_17_23.npy : Generated Caption two baby bears are walking
# two baby bears are walking
#
# Video path C:\Users\User\Documents\P2M\test1\feature\1kYWws89W3Y_0_5.npy : Generated Caption a cat is running and falls
# a cat is running and falls
#
# Video path C:\Users\User\Documents\P2M\test1\feature\wgrrQwLdME8_0_10.npy : Generated Caption a boy is playing a guitar
# a boy is playing a guitar
#
# Video path C:\Users\User\Documents\P2M\test1\feature\z2kUc8wp9l8_40_46.npy : Generated Caption a man is kicking a soccer ball
# a man is kicking a soccer ball
#
# Video path C:\Users\User\Documents\P2M\test1\feature\N2Cm0SLr0ZE_18_29.npy : Generated Caption a boy is playing a guitar
# a boy is playing a guitar
#
# Video path C:\Users\User\Documents\P2M\test1\feature\ZdNP0dXCx2I_78_90.npy : Generated Caption a man and woman are riding a car
# a man and woman are riding a car
#
# Video path C:\Users\User\Documents\P2M\test1\feature\qeKX-N1nKiM_123_130.npy : Generated Caption a woman is cooking meat
# a woman is cooking meat
#
# Video path C:\Users\User\Documents\P2M\test1\feature\-pUwIypksfE_13_23.npy : Generated Caption a panda is playing
# a panda is playing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\lw7pTwpx0K0_38_48.npy : Generated Caption a man is putting a speaker
# a man is putting a speaker
#
# Video path C:\Users\User\Documents\P2M\test1\feature\lb8J2zCQTlo_3_8.npy : Generated Caption a man is cutting meat
# a man is cutting meat
#
# Video path C:\Users\User\Documents\P2M\test1\feature\ge7OOILJA6U_20_25.npy : Generated Caption three men are playing guitars
# three men are playing guitars
#
# Video path C:\Users\User\Documents\P2M\test1\feature\1dfR0A_BXjw_590_600.npy : Generated Caption a man is eating a banana
# a man is eating a banana
#
# Video path C:\Users\User\Documents\P2M\test1\feature\-YI0cxuNcq8_262_272.npy : Generated Caption a woman is exercising
# a woman is exercising
#
# Video path C:\Users\User\Documents\P2M\test1\feature\H9Oplnr8WcE_24_34.npy : Generated Caption a man is riding a boat
# a man is riding a boat
#
# Video path C:\Users\User\Documents\P2M\test1\feature\kZfBt5me3Pg_2_7.npy : Generated Caption a man and woman are riding a bike
# a man and woman are riding a bike
#
# Video path C:\Users\User\Documents\P2M\test1\feature\BE_uxYK9uz0_150_168.npy : Generated Caption a man is cutting a piece of wood
# a man is cutting a piece of wood
#
# Video path C:\Users\User\Documents\P2M\test1\feature\dhxE9CNeVeY_0_12.npy : Generated Caption a boy is sitting on a bed
# a boy is sitting on a bed
#
# Video path C:\Users\User\Documents\P2M\test1\feature\Afmc6FeN-hM_20_24.npy : Generated Caption a group of men are dancing
# a group of men are dancing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\kWLNZzuo3do_222_227.npy : Generated Caption a woman is frying some food
# a woman is frying some food
#
# Video path C:\Users\User\Documents\P2M\test1\feature\9wxB1UQi0MM_18_38.npy : Generated Caption a woman is mixing flour
# a woman is mixing flour
#
# Video path C:\Users\User\Documents\P2M\test1\feature\UJKythlXAIY_17_21.npy : Generated Caption a band is performing on stage
# a band is performing on stage
#
# Video path C:\Users\User\Documents\P2M\test1\feature\IhzXQ-gc9IQ_125_129.npy : Generated Caption two men are driving in a car
# two men are driving in a car
#
# Video path C:\Users\User\Documents\P2M\test1\feature\-4wsuPCjDBc_5_15.npy : Generated Caption a squirrel is eating
# a squirrel is eating
#
# Video path C:\Users\User\Documents\P2M\test1\feature\o_mWZWcm2r4_47_54.npy : Generated Caption a girl is riding a bicycle
# a girl is riding a bicycle
#
# Video path C:\Users\User\Documents\P2M\test1\feature\1RchFBCT9JU_43_53.npy : Generated Caption a hedgehog is eating
# a hedgehog is eating
#
# Video path C:\Users\User\Documents\P2M\test1\feature\-wa0umYJVGg_100_115.npy : Generated Caption a woman is frying eggs
# a woman is frying eggs
#
# Video path C:\Users\User\Documents\P2M\test1\feature\CquJjlNuotg_147_155.npy : Generated Caption a man is cutting a paper
# a man is cutting a paper
#
# Video path C:\Users\User\Documents\P2M\test1\feature\8sARjdhSvpo_167_176.npy : Generated Caption a woman is cutting a vegetable
# a woman is cutting a vegetable
#
# Video path C:\Users\User\Documents\P2M\test1\feature\UbmZAe5u5FI_26_33.npy : Generated Caption a woman is cutting a vegetable
# a woman is cutting a vegetable
#
# Video path C:\Users\User\Documents\P2M\test1\feature\s80J2dAUUyI_33_43.npy : Generated Caption a man is doing exercise
# a man is doing exercise
#
# Video path C:\Users\User\Documents\P2M\test1\feature\e-j59PqJjSM_50_98.npy : Generated Caption a man is cutting a mango
# a man is cutting a mango
#
# Video path C:\Users\User\Documents\P2M\test1\feature\bmxIurBrW5s_51_70.npy : Generated Caption a woman is doing a basketball
# a woman is doing a basketball
#
# Video path C:\Users\User\Documents\P2M\test1\feature\VuCFgiWfVF4_0_6.npy : Generated Caption a man is buying beer
# a man is buying beer
# Video path C:\Users\User\Documents\P2M\test1\feature\umjc1CkO4JA_290_305.npy : Generated Caption a man is cutting a tree
# a man is cutting a tree
#
# Video path C:\Users\User\Documents\P2M\test1\feature\9LHg5RUGukI_58_63.npy : Generated Caption a man is taking a box of a box
# a man is taking a box of a box
#
# Video path C:\Users\User\Documents\P2M\test1\feature\k9Brw_0gncU_14_33.npy : Generated Caption a band is performing on stage
# a band is performing on stage
#
# Video path C:\Users\User\Documents\P2M\test1\feature\ficwZQYmRLE_5_20.npy : Generated Caption a dog is playing with a toy
# a dog is playing with a toy
#
# Video path C:\Users\User\Documents\P2M\test1\feature\hNPZmTlY_3Q_0_8.npy : Generated Caption a man is doing karate arts
# a man is doing karate arts
#
# Video path C:\Users\User\Documents\P2M\test1\feature\0hyZ__3YhZc_380_384.npy : Generated Caption a man is pouring sauce into a pot
# a man is pouring sauce into a pot
#
# Video path C:\Users\User\Documents\P2M\test1\feature\ul9Xvjt83eI_111_120.npy : Generated Caption two men are talking
# two men are talking
#
# Video path C:\Users\User\Documents\P2M\test1\feature\jW77z3-SrO4_56_63.npy : Generated Caption a woman is mixing flour
# a woman is mixing flour
#
# Video path C:\Users\User\Documents\P2M\test1\feature\Qwn0Ni9G5ow_64_69.npy : Generated Caption a group of people are moving down the street
# a group of people are moving down the street
#
# Video path C:\Users\User\Documents\P2M\test1\feature\9uDPqigcnzw_36_46.npy : Generated Caption a man is playing a guitar
# a man is playing a guitar
#
# Video path C:\Users\User\Documents\P2M\test1\feature\pptYu3YQnxY_160_170.npy : Generated Caption a woman is mixing ingredients in a bowl
# a woman is mixing ingredients in a bowl
#
# Video path C:\Users\User\Documents\P2M\test1\feature\0lh_UWF9ZP4_178_182.npy : Generated Caption a woman is cutting shrimp
# a woman is cutting shrimp
#
# Video path C:\Users\User\Documents\P2M\test1\feature\wFX6bXLbHW4_83_90.npy : Generated Caption a man is walking with a man
# a man is walking with a man
#
# Video path C:\Users\User\Documents\P2M\test1\feature\eZLxohGP4IE_147_158.npy : Generated Caption a man is cutting a piece of wood with a knife
# a man is cutting a piece of wood with a knife
#
# Video path C:\Users\User\Documents\P2M\test1\feature\t3VPeyYL-fI_35_39.npy : Generated Caption a man is putting liquid into a pan
# a man is putting liquid into a pan
#
# Video path C:\Users\User\Documents\P2M\test1\feature\6Q3ltyPJJMQ_67_72.npy : Generated Caption a man is lifting weights
# a man is lifting weights
#
# Video path C:\Users\User\Documents\P2M\test1\feature\yg4aNiO1JnI_111_114.npy : Generated Caption a dog is riding a skateboard
# a dog is riding a skateboard
#
# Video path C:\Users\User\Documents\P2M\test1\feature\oDcd2JbOyzg_85_98.npy : Generated Caption a man is cutting a potato
# a man is cutting a potato
#
# Video path C:\Users\User\Documents\P2M\test1\feature\7d1d2WlEnKs_0_12.npy : Generated Caption a cat is playing
# a cat is playing
#
# Video path C:\Users\User\Documents\P2M\test1\feature\fJr2evLANsE_0_10.npy : Generated Caption a cat is playing with a cat
# a cat is playing with a cat
